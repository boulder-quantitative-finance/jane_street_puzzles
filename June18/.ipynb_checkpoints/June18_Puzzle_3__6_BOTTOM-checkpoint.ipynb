# %%
import time
import pandas as pd

# %%
row1_opts = []
row2_opts = []
row3_opts = []
row4_opts = []
row5_opts = []
row6_opts = []
row7_opts = []
for i in range(0,8):
    for j in range(0,8):
        for k in range(0,8):
            for l in range(0,8):
                for m in range(0,8):
                    for n in range(0,8):
                        for o in range(0,8):
                            res = [i,j,k,l,m,n,o]
                            zero_count = len([z for z in res if not z])
                            if i + j + k + l + m + n + o == 20 and zero_count == 3:
                                if i != 1 and i != 4 and j == 4 and k != 1 and k != 4 and l != 1 and l != 4 and m != 1 and m != 4 and n != 1 and n != 4 and o != 1 and o != 4:
                                    row1_opts.append(res)
                                if j != 5 and k == 6 and l == 3 and n == 0 and o == 6:
                                    row2_opts.append(res)
                                if i != 4 and j != 4 and k != 4 and l == 0 and m != 4 and n == 5 and o == 5:
                                    row3_opts.append(res)
                                if i != 1 and i != 4 and j != 1 and j != 4 and k != 1 and k != 4 and l == 4 and m != 1 and m != 4 and n != 1 and n != 4 and o != 1 and o != 4:
                                    row4_opts.append(res)
                                if i == 4 and j == 7 and k != 4 and l == 0 and m == 4 and n != 4 and o != 4:
                                    row5_opts.append(res)
                                if i == 2 and j == 0 and k != 4 and l == 7 and m == 4 and n != 4 and o != 4:
                                    row6_opts.append(res)
                                if i != 4 and j != 4 and k != 4 and l != 4 and m != 4 and n == 1 and o != 4:
                                    row7_opts.append(res)

print(len(row1_opts))    
print(len(row2_opts))
print(row2_opts)
print(len(row3_opts))
print(len(row4_opts))
print(len(row5_opts))
print(len(row6_opts))
print(row6_opts)
print(len(row7_opts))
# Out:
# 240
# 2
# [[0, 0, 6, 3, 5, 0, 6], [5, 0, 6, 3, 0, 0, 6]]
# 18
# 240
# 3
# 3
# [[2, 0, 0, 7, 4, 0, 7], [2, 0, 0, 7, 4, 7, 0], [2, 0, 7, 7, 4, 0, 0]]
# 120

# %%
valid = []
for r in row1_opts:
        print(time.time())
#     if r[4] == 4 and r[5] == 2:
#         print("r")
        for s in row2_opts: 
#             if s[0] == 4 and s[4] == 7 and s[5] == 0:
#                 print(" s")
                for t in row3_opts:  
#                     if t[1] == 6:
#                         print("    t")
                        for u in row4_opts:
#                             if u[1] == 3 and u[2] == 0 and u[3] == 4 and u[4] == 0 and u[5] == 7:
#                                 print("      u")
                                for v in row5_opts:
#                                     if v[5] == 4:
#                                         print("        v")
                                        for w in row6_opts:
#                                             if w[1] == 0 and w[2] == 5 and w[6] == 1:
#                                                 print("          w")
                                                for x in row7_opts:
#                                                     if x[1] == 6 and x[2] == 5:
#                                                         print("            x")

                                                        c1 = [r[0],s[0],t[0],u[0],v[0],w[0],x[0]]
                                                        c1_zc = len([z for z in c1 if not z])
                                                        c2 = [r[1],s[1],t[1],u[1],v[1],w[1],x[1]]
                                                        c2_zc = len([z for z in c2 if not z])
                                                        c3 = [r[2],s[2],t[2],u[2],v[2],w[2],x[2]]
                                                        c3_zc = len([z for z in c3 if not z])
                                                        c4 = [r[3],s[3],t[3],u[3],v[3],w[3],x[3]]
                                                        c4_zc = len([z for z in c4 if not z])
                                                        c5 = [r[4],s[4],t[4],u[4],v[4],w[4],x[4]]
                                                        c5_zc = len([z for z in c5 if not z])
                                                        c6 = [r[5],s[5],t[5],u[5],v[5],w[5],x[5]]
                                                        c6_zc = len([z for z in c6 if not z])
                                                        c7 = [r[6],s[6],t[6],u[6],v[6],w[6],x[6]]
                                                        c7_zc = len([z for z in c7 if not z])

                                                        if (sum(c1) == 20 and c1_zc == 3 and 
                                                            sum(c2) == 20 and c2_zc == 3 and 
                                                            sum(c3) == 20 and c3_zc == 3 and 
                                                            sum(c4) == 20 and c4_zc == 3 and
                                                            sum(c5) == 20 and c5_zc == 3 and
                                                            sum(c6) == 20 and c6_zc == 3 and
                                                            sum(c7) == 20 and c7_zc == 3):
                                                            
                                                            valid_grid = [r,s,t,u,v,w,x]
                                                            valid.append(valid_grid)
#                                                             print(valid_grid)

print(valid)
# Out:
# 1528308576.060757
# 1528308641.789601
# 1528308708.2663019
# 1528308774.7121851
# 1528308839.909099
# 1528308902.4311721
# 1528308965.143394
# 1528309027.814025
# 1528309090.278661
# 1528309152.6192598
# 1528309216.0280042
# 1528309278.730546
# 1528309346.0266728
# 1528309413.068413
# 1528309478.6857972
# 1528309544.776884
# 1528309612.842328
# 1528309680.0074182
# 1528309747.9737432
# 1528309813.1611829
# 1528309879.43772
# 1528309946.103188
# 1528310010.991831
# 1528310075.5047429
# 1528310140.523962
# 1528310204.827009
# 1528310270.177697
# 1528310333.885522
# 1528310397.166877
# 1528310462.024053
# 1528310528.3522089
# 1528310594.705302
# 1528310659.31481
# 1528310731.0332701
# 1528310796.23724
# 1528310862.648417
# 1528310929.816281
# 1528310996.9029949
# 1528311063.583054

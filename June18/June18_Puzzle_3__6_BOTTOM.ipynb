# %%
import time
import pandas as pd

# %%
row1_opts = []
row2_opts = []
row3_opts = []
row4_opts = []
row5_opts = []
row6_opts = []
row7_opts = []
for i in range(0,8):
    for j in range(0,8):
        for k in range(0,8):
            for l in range(0,8):
                for m in range(0,8):
                    for n in range(0,8):
                        for o in range(0,8):
                            res = [i,j,k,l,m,n,o]
                            zero_count = len([z for z in res if not z])
                            if i + j + k + l + m + n + o == 20 and zero_count == 3:
                                if i != 1 and i != 4 and j == 4 and k != 1 and k != 4 and l == 0 and m != 1 and m != 4 and n != 1 and n != 4 and o != 1 and o != 4:
                                    row1_opts.append(res)
                                if i != 1 and i != 4 and j != 1 and j != 4 and j != 5 and k == 6 and l == 3 and m != 1 and m != 4 and n == 0 and o == 6:
                                    row2_opts.append(res)
                                if i != 1 and i != 4 and j != 1 and j != 4 and k != 1 and k != 4 and l != 1 and l != 4 and m != 1 and m != 4 and n == 5 and o == 5:
                                    row3_opts.append(res)
                                if i != 1 and i != 4 and j != 1 and j != 4 and k != 1 and k != 4 and l == 4 and m != 1 and m != 4 and n != 1 and n != 4 and o != 1 and o != 4:
                                    row4_opts.append(res)
                                if i == 4 and j == 7 and k != 1 and k != 4 and l == 0 and m != 1 and m != 4 and n != 1 and n != 4 and o != 1 and o != 4:
                                    row5_opts.append(res)
                                if i == 2 and j == 0 and k != 1 and k != 4 and l == 7 and m == 4 and n != 1 and n != 4 and o != 1 and o != 4:
                                    row6_opts.append(res)
                                if i != 1 and i != 4 and j != 1 and j != 4 and k != 1 and k != 4 and l == 6 and m == 0 and n == 1 and o != 1 and o != 4:
                                    row7_opts.append(res)

print(len(row1_opts))    
print(len(row2_opts))
# print(row2_opts)
print(len(row3_opts))
print(len(row4_opts))
print(len(row5_opts))
print(len(row6_opts))
# print(row6_opts)
print(len(row7_opts))
# Out:
# 120
# 2
# 30
# 240
# 24
# 3
# 12

# %%
valid = []
for r in row1_opts:
        print(time.time())
#     if r[4] == 4 and r[5] == 2:
#         print("r")
        for s in row2_opts: 
#             if s[0] == 4 and s[4] == 7 and s[5] == 0:
#                 print(" s")
                for t in row3_opts:  
#                     if t[1] == 6:
#                         print("    t")
                        for u in row4_opts:
#                             if u[1] == 3 and u[2] == 0 and u[3] == 4 and u[4] == 0 and u[5] == 7:
#                                 print("      u")
                                for v in row5_opts:
#                                     if v[5] == 4:
#                                         print("        v")
                                        for w in row6_opts:
#                                             if w[1] == 0 and w[2] == 5 and w[6] == 1:
#                                                 print("          w")
                                                for x in row7_opts:
#                                                     if x[1] == 6 and x[2] == 5:
#                                                         print("            x")

                                                        c1 = [r[0],s[0],t[0],u[0],v[0],w[0],x[0]]
                                                        c1_zc = len([z for z in c1 if not z])
                                                        c2 = [r[1],s[1],t[1],u[1],v[1],w[1],x[1]]
                                                        c2_zc = len([z for z in c2 if not z])
                                                        c3 = [r[2],s[2],t[2],u[2],v[2],w[2],x[2]]
                                                        c3_zc = len([z for z in c3 if not z])
                                                        c4 = [r[3],s[3],t[3],u[3],v[3],w[3],x[3]]
                                                        c4_zc = len([z for z in c4 if not z])
                                                        c5 = [r[4],s[4],t[4],u[4],v[4],w[4],x[4]]
                                                        c5_zc = len([z for z in c5 if not z])
                                                        c6 = [r[5],s[5],t[5],u[5],v[5],w[5],x[5]]
                                                        c6_zc = len([z for z in c6 if not z])
                                                        c7 = [r[6],s[6],t[6],u[6],v[6],w[6],x[6]]
                                                        c7_zc = len([z for z in c7 if not z])

                                                        if (sum(c1) == 20 and c1_zc == 3 and 
                                                            sum(c2) == 20 and c2_zc == 3 and 
                                                            sum(c3) == 20 and c3_zc == 3 and 
                                                            sum(c4) == 20 and c4_zc == 3 and
                                                            sum(c5) == 20 and c5_zc == 3 and
                                                            sum(c6) == 20 and c6_zc == 3 and
                                                            sum(c7) == 20 and c7_zc == 3):
                                                            
                                                            valid_grid = [r,s,t,u,v,w,x]
                                                            valid.append(valid_grid)
#                                                             print(valid_grid)

print(valid)
# Out:
# 1528320015.895493
# 1528320092.7424388
# 1528320171.575947
# 1528320248.962602
# 1528320326.8675709
# 1528320407.001023
# 1528320484.393755
# 1528320561.307416
# 1528320638.874814
# 1528320715.3961039
# 1528320792.9887738
# 1528320869.589639
# 1528320946.2711868
# 1528321023.56445
# 1528321100.459837
# 1528321176.326209
# 1528321252.3223019
# 1528321329.8260648
# 1528321404.684428
# 1528321481.119018
# 1528321555.538937
# 1528321631.018531
# 1528321706.066124
# 1528321780.601313
# 1528321854.941844
# 1528321931.25379
# 1528322005.9064
# 1528322081.297301
# 1528322157.160976
# 1528322233.499995
# 1528322309.488631
# 1528322385.64286
# 1528322463.929739
# 1528322540.7209868
# 1528322616.371436
# 1528322691.7370272
# 1528322766.982815
# 1528322842.460895
# 1528322917.423926
# 1528322991.9296708
# 1528323066.560971
# 1528323140.962751
# 1528323214.932468
# 1528323288.9133298
# 1528323368.499051
# 1528323443.669579
# 1528323518.295671
# 1528323593.3180218
# 1528323668.347035
# ...

# %%
print(len(valid))
really_valid = []
for i in valid:
    ones = 0
    twos = 0
    threes = 0
    fours = 0
    fives = 0
    sixes = 0
    sevens = 0
    for j in i:
        for k in j:
#             print(k)
            if k == 1:
                ones = ones+1
            if k == 2:
                twos = twos+1
            if k == 3:
                threes = threes+1
            if k == 4:
                fours = fours+1
            if k == 5:
                fives = fives+1
            if k == 6:
                sixes = sixes+1
            if k == 7:
                sevens = sevens+1
#     print(ones)
#     print(twos)
#     print(threes)
#     print(fours)
#     print(fives)
#     print(sixes)
#     print(sevens)
#     for b in i:
#         print(b)
#     print("-------")
    if ones == 1 and twos == 2 and threes == 3 and fours == 4 and fives == 5 and sixes == 6 and sevens == 7:
        really_valid.append(i)
print(len(really_valid))
print(really_valid)
# Out:
# 102
# 44
# ...
